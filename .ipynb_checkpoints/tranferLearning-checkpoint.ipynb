# %%
import torch
import torchvision.models as models
from torchvision.models import ResNet18_Weights

# Load pre-trained ResNet18 using the new weights argument
model = models.resnet18(weights=ResNet18_Weights.DEFAULT)

# Modify the final layer for 4 classes
num_ftrs = model.fc.in_features
model.fc = torch.nn.Linear(num_ftrs, 4)  # 4 food categories

# Set device (GPU, MPS, or CPU)
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Using device: {device}")

# Move the model to the chosen device
model = model.to(device)
# Out:
# Using device: mps

# %%
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader

# Define dataset paths
train_dir = "CustomDataSet/data/train"
test_dir = "CustomDataSet/data/test"

# Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize to match ResNet input size
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Load dataset
train_dataset = datasets.ImageFolder(root=train_dir, transform=transform)
test_dataset = datasets.ImageFolder(root=test_dir, transform=transform)

# Create DataLoaders
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-4)

# %%
from trainNN import train

# Train the model for 10 epochs
results = train(
    model=model,
    train_dataloader=train_dataloader,
    test_dataloader=test_dataloader,
    optimizer=optimizer,
    loss_fn=loss_fn,
    epochs=20,
    device=device
)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 0.3411 | train_acc: 0.8842 | test_loss: 0.0790 | test_acc: 0.9788
# [INFO] New best model found! Saving model...
# Epoch: 2 | train_loss: 0.0570 | train_acc: 0.9879 | test_loss: 0.0929 | test_acc: 0.9600
# Epoch: 3 | train_loss: 0.0159 | train_acc: 0.9992 | test_loss: 0.0631 | test_acc: 0.9775
# Epoch: 4 | train_loss: 0.0078 | train_acc: 1.0000 | test_loss: 0.0616 | test_acc: 0.9800
# [INFO] New best model found! Saving model...
# Epoch: 5 | train_loss: 0.0049 | train_acc: 0.9996 | test_loss: 0.0616 | test_acc: 0.9788
# Epoch: 6 | train_loss: 0.0043 | train_acc: 0.9996 | test_loss: 0.0563 | test_acc: 0.9800
# Epoch: 7 | train_loss: 0.0043 | train_acc: 0.9996 | test_loss: 0.0730 | test_acc: 0.9712
# Epoch: 8 | train_loss: 0.0056 | train_acc: 0.9988 | test_loss: 0.0703 | test_acc: 0.9762
# Epoch: 9 | train_loss: 0.0025 | train_acc: 1.0000 | test_loss: 0.0652 | test_acc: 0.9788
# Epoch: 10 | train_loss: 0.0041 | train_acc: 0.9992 | test_loss: 0.0620 | test_acc: 0.9812
# [INFO] New best model found! Saving model...
# Epoch: 11 | train_loss: 0.0168 | train_acc: 0.9954 | test_loss: 0.1325 | test_acc: 0.9613
# Epoch: 12 | train_loss: 0.0450 | train_acc: 0.9846 | test_loss: 0.2519 | test_acc: 0.9200
# Epoch: 13 | train_loss: 0.0560 | train_acc: 0.9825 | test_loss: 0.1401 | test_acc: 0.9425
# Epoch: 14 | train_loss: 0.0342 | train_acc: 0.9908 | test_loss: 0.0770 | test_acc: 0.9750
# Epoch: 15 | train_loss: 0.0198 | train_acc: 0.9954 | test_loss: 0.1059 | test_acc: 0.9600
# Epoch: 16 | train_loss: 0.0119 | train_acc: 0.9967 | test_loss: 0.0615 | test_acc: 0.9762
# Epoch: 17 | train_loss: 0.0050 | train_acc: 0.9988 | test_loss: 0.0764 | test_acc: 0.9762
# Epoch: 18 | train_loss: 0.0035 | train_acc: 0.9996 | test_loss: 0.0698 | test_acc: 0.9738
# Epoch: 19 | train_loss: 0.0026 | train_acc: 0.9992 | test_loss: 0.0726 | test_acc: 0.9762
# Epoch: 20 | train_loss: 0.0057 | train_acc: 0.9988 | test_loss: 0.0865 | test_acc: 0.9738
# [INFO] Best model saved to best_model.pth

# %%
torch.save(model.state_dict(), "transfer_learning.pth")

# %%
from helper_functions import plot_loss_curves
# Plot the loss curves of our model
plot_loss_curves(results)
