# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("LED.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Adult Mortality                  2928 non-null   float64
#  4   infant deaths                    2938 non-null   int64
#  5   Alcohol                          2744 non-null   float64
#  6   percentage expenditure           2938 non-null   float64
#  7   Hepatitis B                      2385 non-null   float64
#  8   Measles                          2938 non-null   int64
#  9    BMI                             2904 non-null   float64
#  10  under-five deaths                2938 non-null   int64
#  11  Polio                            2919 non-null   float64
#  12  Total expenditure                2712 non-null   float64
#  13  Diphtheria                       2919 non-null   float64
#  14   HIV                             2938 non-null   float64
#  15  GDP                              2490 non-null   float64
#  16  Population                       2286 non-null   float64
#  17   thinness  1-19 years            2904 non-null   float64
#  18   thinness 5-9 years              2904 non-null   float64
#  19  Income composition of resources  2771 non-null   float64
#  20  Schooling                        2775 non-null   float64
#  21  Life expectancy                  2928 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %%
df
# Out:
#           Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0     Afghanistan  2015  Developing            263.0             62     0.01
# 1     Afghanistan  2014  Developing            271.0             64     0.01
# 2     Afghanistan  2013  Developing            268.0             66     0.01
# 3     Afghanistan  2012  Developing            272.0             69     0.01
# 4     Afghanistan  2011  Developing            275.0             71     0.01
# ...           ...   ...         ...              ...            ...      ...
# 2933     Zimbabwe  2004  Developing            723.0             27     4.36
# 2934     Zimbabwe  2003  Developing            715.0             26     4.06
# 2935     Zimbabwe  2002  Developing             73.0             25     4.43
# 2936     Zimbabwe  2001  Developing            686.0             25     1.72
# 2937     Zimbabwe  2000  Developing            665.0             24     1.68
#
#       percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0                  71.279624         65.0      1154   19.1  ...
# 1                  73.523582         62.0       492   18.6  ...
# 2                  73.219243         64.0       430   18.1  ...
# 3                  78.184215         67.0      2787   17.6  ...
# 4                   7.097109         68.0      3013   17.2  ...
# ...                      ...          ...       ...    ...  ...
# 2933                0.000000         68.0        31   27.1  ...
# 2934                0.000000          7.0       998   26.7  ...
# 2935                0.000000         73.0       304   26.3  ...
# 2936                0.000000         76.0       529   25.9  ...
# 2937                0.000000         79.0      1483   25.5  ...
#
#       Total expenditure  Diphtheria    HIV         GDP  Population  \
# 0                  8.16         65.0   0.1  584.259210  33736494.0
# 1                  8.18         62.0   0.1  612.696514    327582.0
# 2                  8.13         64.0   0.1  631.744976  31731688.0
# 3                  8.52         67.0   0.1  669.959000   3696958.0
# 4                  7.87         68.0   0.1   63.537231   2978599.0
# ...                 ...          ...   ...         ...         ...
# 2933               7.13         65.0  33.6  454.366654  12777511.0
# 2934               6.52         68.0  36.7  453.351155  12633897.0
# 2935               6.53         71.0  39.8   57.348340    125525.0
# 2936               6.16         75.0  42.1  548.587312  12366165.0
# 2937               7.10         78.0  43.5  547.358878  12222251.0
#
#        thinness  1-19 years   thinness 5-9 years  \
# 0                      17.2                 17.3
# 1                      17.5                 17.5
# 2                      17.7                 17.7
# 3                      17.9                 18.0
# 4                      18.2                 18.2
# ...                     ...                  ...
# 2933                    9.4                  9.4
# 2934                    9.8                  9.9
# 2935                    1.2                  1.3
# 2936                    1.6                  1.7
# 2937                   11.0                 11.2
#
#       Income composition of resources  Schooling  Life expectancy
# 0                               0.479       10.1             65.0
# 1                               0.476       10.0             59.9
# 2                               0.470        9.9             59.9
# 3                               0.463        9.8             59.5
# 4                               0.454        9.5             59.2
# ...                               ...        ...              ...
# 2933                            0.407        9.2             44.3
# 2934                            0.418        9.5             44.5
# 2935                            0.427       10.0             44.8
# 2936                            0.427        9.8             45.3
# 2937                            0.434        9.8             46.0
#
# [2938 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Adult Mortality                  2928 non-null   float64
#  4   infant deaths                    2938 non-null   int64
#  5   Alcohol                          2744 non-null   float64
#  6   percentage expenditure           2938 non-null   float64
#  7   Hepatitis B                      2385 non-null   float64
#  8   Measles                          2938 non-null   int64
#  9    BMI                             2904 non-null   float64
#  10  under-five deaths                2938 non-null   int64
#  11  Polio                            2919 non-null   float64
#  12  Total expenditure                2712 non-null   float64
#  13  Diphtheria                       2919 non-null   float64
#  14   HIV                             2938 non-null   float64
#  15  GDP                              2490 non-null   float64
#  16  Population                       2286 non-null   float64
#  17   thinness  1-19 years            2904 non-null   float64
#  18   thinness 5-9 years              2904 non-null   float64
#  19  Income composition of resources  2771 non-null   float64
#  20  Schooling                        2775 non-null   float64
#  21  Life expectancy                  2928 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %%
df.describe()
# Out:
#               Year  Adult Mortality  infant deaths      Alcohol  \
# count  2938.000000      2928.000000    2938.000000  2744.000000
# mean   2007.518720       164.796448      30.303948     4.602861
# std       4.613841       124.292079     117.926501     4.052413
# min    2000.000000         1.000000       0.000000     0.010000
# 25%    2004.000000        74.000000       0.000000     0.877500
# 50%    2008.000000       144.000000       3.000000     3.755000
# 75%    2012.000000       228.000000      22.000000     7.702500
# max    2015.000000       723.000000    1800.000000    17.870000
#
#        percentage expenditure  Hepatitis B       Measles          BMI   \
# count             2938.000000  2385.000000    2938.000000  2904.000000
# mean               738.251295    80.940461    2419.592240    38.321247
# std               1987.914858    25.070016   11467.272489    20.044034
# min                  0.000000     1.000000       0.000000     1.000000
# 25%                  4.685343    77.000000       0.000000    19.300000
# 50%                 64.912906    92.000000      17.000000    43.500000
# 75%                441.534144    97.000000     360.250000    56.200000
# max              19479.911610    99.000000  212183.000000    87.300000
#
#        under-five deaths         Polio  Total expenditure  Diphtheria   \
# count         2938.000000  2919.000000         2712.00000  2919.000000
# mean            42.035739    82.550188            5.93819    82.324084
# std            160.445548    23.428046            2.49832    23.716912
# min              0.000000     3.000000            0.37000     2.000000
# 25%              0.000000    78.000000            4.26000    78.000000
# 50%              4.000000    93.000000            5.75500    93.000000
# 75%             28.000000    97.000000            7.49250    97.000000
# max           2500.000000    99.000000           17.60000    99.000000
#
#                HIV            GDP    Population   thinness  1-19 years  \
# count  2938.000000    2490.000000  2.286000e+03            2904.000000
# mean      1.742103    7483.158469  1.275338e+07               4.839704
# std       5.077785   14270.169342  6.101210e+07               4.420195
# min       0.100000       1.681350  3.400000e+01               0.100000
# 25%       0.100000     463.935626  1.957932e+05               1.600000
# 50%       0.100000    1766.947595  1.386542e+06               3.300000
# 75%       0.800000    5910.806335  7.420359e+06               7.200000
# max      50.600000  119172.741800  1.293859e+09              27.700000
#
#         thinness 5-9 years  Income composition of resources    Schooling  \
# count          2904.000000                      2771.000000  2775.000000
# mean              4.870317                         0.627551    11.992793
# std               4.508882                         0.210904     3.358920
# min               0.100000                         0.000000     0.000000
# 25%               1.500000                         0.493000    10.100000
# 50%               3.300000                         0.677000    12.300000
# 75%               7.200000                         0.779000    14.300000
# max              28.600000                         0.948000    20.700000
#
#        Life expectancy
# count      2928.000000
# mean         69.224932
# std           9.523867
# min          36.300000
# 25%          63.100000
# 50%          72.100000
# 75%          75.700000
# max          89.000000

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.head()
# Out:
#        Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan  2015  Developing            263.0             62     0.01
# 1  Afghanistan  2014  Developing            271.0             64     0.01
# 2  Afghanistan  2013  Developing            268.0             66     0.01
# 3  Afghanistan  2012  Developing            272.0             69     0.01
# 4  Afghanistan  2011  Developing            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0               71.279624         65.0      1154   19.1  ...
# 1               73.523582         62.0       492   18.6  ...
# 2               73.219243         64.0       430   18.1  ...
# 3               78.184215         67.0      2787   17.6  ...
# 4                7.097109         68.0      3013   17.2  ...
#
#    Total expenditure  Diphtheria    HIV         GDP  Population  \
# 0               8.16         65.0   0.1  584.259210  33736494.0
# 1               8.18         62.0   0.1  612.696514    327582.0
# 2               8.13         64.0   0.1  631.744976  31731688.0
# 3               8.52         67.0   0.1  669.959000   3696958.0
# 4               7.87         68.0   0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling  Life expectancy
# 0                            0.479       10.1             65.0
# 1                            0.476       10.0             59.9
# 2                            0.470        9.9             59.9
# 3                            0.463        9.8             59.5
# 4                            0.454        9.5             59.2
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#        Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 2933  Zimbabwe  2004  Developing            723.0             27     4.36
# 2934  Zimbabwe  2003  Developing            715.0             26     4.06
# 2935  Zimbabwe  2002  Developing             73.0             25     4.43
# 2936  Zimbabwe  2001  Developing            686.0             25     1.72
# 2937  Zimbabwe  2000  Developing            665.0             24     1.68
#
#       percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 2933                     0.0         68.0        31   27.1  ...
# 2934                     0.0          7.0       998   26.7  ...
# 2935                     0.0         73.0       304   26.3  ...
# 2936                     0.0         76.0       529   25.9  ...
# 2937                     0.0         79.0      1483   25.5  ...
#
#       Total expenditure  Diphtheria    HIV         GDP  Population  \
# 2933               7.13         65.0  33.6  454.366654  12777511.0
# 2934               6.52         68.0  36.7  453.351155  12633897.0
# 2935               6.53         71.0  39.8   57.348340    125525.0
# 2936               6.16         75.0  42.1  548.587312  12366165.0
# 2937               7.10         78.0  43.5  547.358878  12222251.0
#
#        thinness  1-19 years   thinness 5-9 years  \
# 2933                    9.4                  9.4
# 2934                    9.8                  9.9
# 2935                    1.2                  1.3
# 2936                    1.6                  1.7
# 2937                   11.0                 11.2
#
#       Income composition of resources  Schooling  Life expectancy
# 2933                            0.407        9.2             44.3
# 2934                            0.418        9.5             44.5
# 2935                            0.427       10.0             44.8
# 2936                            0.427        9.8             45.3
# 2937                            0.434        9.8             46.0
#
# [5 rows x 22 columns]

# %%
df.dropna(inplace=True,axis=0)

# %%
df.shape
# Out:
# (1649, 22)

# %%
df.head(10)
# Out:
#        Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan  2015  Developing            263.0             62     0.01
# 1  Afghanistan  2014  Developing            271.0             64     0.01
# 2  Afghanistan  2013  Developing            268.0             66     0.01
# 3  Afghanistan  2012  Developing            272.0             69     0.01
# 4  Afghanistan  2011  Developing            275.0             71     0.01
# 5  Afghanistan  2010  Developing            279.0             74     0.01
# 6  Afghanistan  2009  Developing            281.0             77     0.01
# 7  Afghanistan  2008  Developing            287.0             80     0.03
# 8  Afghanistan  2007  Developing            295.0             82     0.02
# 9  Afghanistan  2006  Developing            295.0             84     0.03
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0               71.279624         65.0      1154   19.1  ...
# 1               73.523582         62.0       492   18.6  ...
# 2               73.219243         64.0       430   18.1  ...
# 3               78.184215         67.0      2787   17.6  ...
# 4                7.097109         68.0      3013   17.2  ...
# 5               79.679367         66.0      1989   16.7  ...
# 6               56.762217         63.0      2861   16.2  ...
# 7               25.873925         64.0      1599   15.7  ...
# 8               10.910156         63.0      1141   15.2  ...
# 9               17.171518         64.0      1990   14.7  ...
#
#    Total expenditure  Diphtheria    HIV         GDP  Population  \
# 0               8.16         65.0   0.1  584.259210  33736494.0
# 1               8.18         62.0   0.1  612.696514    327582.0
# 2               8.13         64.0   0.1  631.744976  31731688.0
# 3               8.52         67.0   0.1  669.959000   3696958.0
# 4               7.87         68.0   0.1   63.537231   2978599.0
# 5               9.20         66.0   0.1  553.328940   2883167.0
# 6               9.42         63.0   0.1  445.893298    284331.0
# 7               8.33         64.0   0.1  373.361116   2729431.0
# 8               6.73         63.0   0.1  369.835796  26616792.0
# 9               7.43         58.0   0.1  272.563770   2589345.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
# 5                   18.4                 18.4
# 6                   18.6                 18.7
# 7                   18.8                 18.9
# 8                   19.0                 19.1
# 9                   19.2                 19.3
#
#    Income composition of resources  Schooling  Life expectancy
# 0                            0.479       10.1             65.0
# 1                            0.476       10.0             59.9
# 2                            0.470        9.9             59.9
# 3                            0.463        9.8             59.5
# 4                            0.454        9.5             59.2
# 5                            0.448        9.2             58.8
# 6                            0.434        8.9             58.6
# 7                            0.433        8.7             58.1
# 8                            0.415        8.4             57.5
# 9                            0.405        8.1             57.3
#
# [10 rows x 22 columns]

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of       Country   Year  Status  Adult Mortality  infant deaths  Alcohol  \
# 0       False  False   False            False          False    False
# 1       False  False   False            False          False    False
# 2       False  False   False            False          False    False
# 3       False  False   False            False          False    False
# 4       False  False   False            False          False    False
# ...       ...    ...     ...              ...            ...      ...
# 2933    False  False   False            False          False    False
# 2934    False  False   False            False          False    False
# 2935    False  False   False            False          False    False
# 2936    False  False   False            False          False    False
# 2937    False  False   False            False          False    False
#
#       percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0                      False        False     False  False  ...
# 1                      False        False     False  False  ...
# 2                      False        False     False  False  ...
# 3                      False        False     False  False  ...
# 4                      False        False     False  False  ...
# ...                      ...          ...       ...    ...  ...
# 2933                   False        False     False  False  ...
# 2934                   False        False     False  False  ...
# 2935                   False        False     False  False  ...
# 2936                   False        False     False  False  ...
# 2937                   False        False     False  False  ...
#
#       Total expenditure  Diphtheria     HIV    GDP  Population  \
# 0                 False        False  False  False       False
# 1                 False        False  False  False       False
# 2                 False        False  False  False       False
# 3                 False        False  False  False       False
# 4                 False        False  False  False       False
# ...                 ...          ...    ...    ...         ...
# 2933              False        False  False  False       False
# 2934              False        False  False  False       False
# 2935              False        False  False  False       False
# 2936              False        False  False  False       False
# 2937              False        False  False  False       False
#
#        thinness  1-19 years   thinness 5-9 years  \
# 0                     False                False
# 1                     False                False
# 2                     False                False
# 3                     False                False
# 4                     False                False
# ...                     ...                  ...
# 2933                  False                False
# 2934                  False                False
# 2935                  False                False
# 2936                  False                False
# 2937                  False                False
#
#       Income composition of resources  Schooling  Life expectancy
# 0                               False      False            False
# 1                               False      False            False
# 2                               False      False            False
# 3                               False      False            False
# 4                               False      False            False
# ...                               ...        ...              ...
# 2933                            False      False            False
# 2934                            False      False            False
# 2935                            False      False            False
# 2936                            False      False            False
# 2937                            False      False            False
#
# [1649 rows x 22 columns]>

# %%
df.isnull().values.any()
# Out:
# np.False_

# %%
df.shape
# Out:
# (1649, 22)

# %%
x= df.drop(columns=["Life expectancy","Country","Status"])
y=df[["Life expectancy"]]
print(x.head())
print(y.tail())
# Out:
#    Year  Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 0  2015            263.0             62     0.01               71.279624
# 1  2014            271.0             64     0.01               73.523582
# 2  2013            268.0             66     0.01               73.219243
# 3  2012            272.0             69     0.01               78.184215
# 4  2011            275.0             71     0.01                7.097109
#
#    Hepatitis B  Measles    BMI   under-five deaths   Polio  Total expenditure  \
# 0         65.0      1154   19.1                  83    6.0               8.16
# 1         62.0       492   18.6                  86   58.0               8.18
# 2         64.0       430   18.1                  89   62.0               8.13
# 3         67.0      2787   17.6                  93   67.0               8.52
# 4         68.0      3013   17.2                  97   68.0               7.87
#
#    Diphtheria    HIV         GDP  Population   thinness  1-19 years  \
# 0         65.0   0.1  584.259210  33736494.0                   17.2
# 1         62.0   0.1  612.696514    327582.0                   17.5
# 2         64.0   0.1  631.744976  31731688.0                   17.7
# 3         67.0   0.1  669.959000   3696958.0                   17.9
# 4         68.0   0.1   63.537231   2978599.0                   18.2
#
#     thinness 5-9 years  Income composition of resources  Schooling
# 0                 17.3                            0.479       10.1
# 1                 17.5                            0.476       10.0
# 2                 17.7                            0.470        9.9
# 3                 18.0                            0.463        9.8
# 4                 18.2                            0.454        9.5
#       Life expectancy
# 2933             44.3
# 2934             44.5
# 2935             44.8
# 2936             45.3
# 2937             46.0

# %%
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV                               0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# Life expectancy                    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=45)
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
#       Year  Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 1559  2010            248.0             32     1.03               76.604422
# 1976  2014            278.0             10     0.01              208.231160
# 1012  2013            254.0             38     0.01               28.668978
# 772   2013            157.0              6     5.93               97.522115
# 1604  2013             64.0              0     0.01             1626.591186
# ...    ...              ...            ...      ...                     ...
# 257   2014            177.0              0     6.58              670.092088
# 1040  2001             83.0              1     8.62             1403.022211
# 2733  2012             25.0              5     8.44              453.783085
# 675   2013             54.0              0     9.04              212.085926
# 1658  2008            217.0              8     0.02               61.762638
#
#       Hepatitis B  Measles    BMI   under-five deaths   Polio  \
# 1559          7.0         1   18.0                  45    7.0
# 1976         67.0      2299   47.9                  13   64.0
# 1012          9.0       319   27.3                  55   91.0
# 772           8.0         0   56.8                   7   82.0
# 1604         99.0         0   25.1                   0   99.0
# ...           ...       ...    ...                 ...    ...
# 257          95.0         0    5.1                   0   95.0
# 1040          9.0        12   58.0                   1    9.0
# 2733         46.0     12746   59.6                   5   72.0
# 675          96.0         0   59.2                   0   99.0
# 1658         74.0         4   26.1                  12   73.0
#
#       Total expenditure  Diphtheria    HIV           GDP  Population  \
# 1559               4.86          7.0   0.5    412.739341   2115164.0
# 1976               4.26         73.0   0.7   2182.716565   7755785.0
# 1012               4.63          9.0   0.9   1814.492297  26346251.0
# 772                4.12         83.0   0.3    627.555440   1281296.0
# 1604              11.16         99.0   0.1   7112.335750       393.0
# ...                 ...          ...   ...           ...         ...
# 257                5.79         95.0   0.2   4852.223666    351694.0
# 1040               8.47         91.0   0.1  12538.178830   1862132.0
# 2733               7.47         76.0   0.2   3855.421280    455933.0
# 675                7.46         99.0   0.1   2797.967360   1143896.0
# 1658               3.23         74.0   1.3   1167.535689    347541.0
#
#        thinness  1-19 years   thinness 5-9 years  \
# 1559                    7.6                  7.5
# 1976                    1.3                  1.3
# 1012                    6.6                  6.4
# 772                     3.3                  3.2
# 1604                   13.7                 13.8
# ...                     ...                  ...
# 257                     3.4                  3.4
# 1040                    0.9                  0.8
# 2733                    2.4                  2.4
# 675                     0.9                  1.0
# 1658                    9.2                  8.9
#
#       Income composition of resources  Schooling
# 1559                            0.503       10.2
# 1976                            0.511       10.0
# 1012                            0.570       11.5
# 772                             0.709       13.2
# 1604                            0.683       12.4
# ...                               ...        ...
# 257                             0.705       12.8
# 1040                            0.801       14.2
# 2733                            0.739       15.1
# 675                             0.850       13.8
# 1658                            0.475        7.2
#
# [1319 rows x 19 columns]
#       Year  Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 0     2015            263.0             62     0.01               71.279624
# 2737  2008            273.0              5     9.46              456.458666
# 34    2013            112.0             21     0.53              544.450743
# 2715  2014             38.0             68     0.01               14.167702
# 2025  2013            219.0             55     4.61               24.589734
# ...    ...              ...            ...      ...                     ...
# 2482  2006            199.0              0     4.52               72.800168
# 359   2008            158.0             61     7.21              526.378064
# 2286  2010             18.0              0     6.51               16.492323
# 199   2008            147.0            144     0.01               42.488650
# 517   2010            446.0             17     1.67               43.483592
#
#       Hepatitis B  Measles    BMI   under-five deaths   Polio  \
# 0            65.0      1154   19.1                  83    6.0
# 2737         84.0        48   57.6                   6   91.0
# 34           95.0        25   57.2                  24   95.0
# 2715         78.0       314   18.1                  97   82.0
# 2025         89.0      2920   24.3                  69   84.0
# ...           ...       ...    ...                 ...    ...
# 2482         84.0         0   51.8                   0   84.0
# 359          96.0         0    5.3                  68   99.0
# 2286         99.0         0   33.5                   0   99.0
# 199          96.0      2660   14.0                 186   96.0
# 517          45.0         2    2.2                  24   46.0
#
#       Total expenditure  Diphtheria    HIV          GDP  Population  \
# 0                  8.16         65.0   0.1   584.259210  33736494.0
# 2737               6.63          9.0   0.4  3891.378230    462582.0
# 34                 7.12         95.0   0.1  5471.866766  38338562.0
# 2715               7.22         78.0   3.2   719.172669  38833338.0
# 2025               4.56         89.0   0.1   276.289146   9848132.0
# ...                 ...          ...   ...          ...         ...
# 2482               6.22         84.0   0.6   527.920000      5437.0
# 359                8.24         99.0   0.1  8787.613750  19297929.0
# 2286               3.59         99.0   0.1   184.684470      8977.0
# 199                2.85         96.0   0.1   615.777541  14885814.0
# 517                3.90         45.0   6.6   446.443449   4448525.0
#
#        thinness  1-19 years   thinness 5-9 years  \
# 0                      17.2                 17.3
# 2737                    2.5                  2.6
# 34                      5.9                  5.8
# 2715                    5.7                  5.6
# 2025                    1.0                  9.7
# ...                     ...                  ...
# 2482                    3.5                  3.4
# 359                     3.0                  3.0
# 2286                    5.8                  6.2
# 199                    19.3                 19.9
# 517                     9.0                  8.9
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 2737                            0.730       14.9
# 34                              0.737       14.4
# 2715                            0.483       10.0
# 2025                            0.671       11.7
# ...                               ...        ...
# 2482                            0.678       11.5
# 359                             0.704       13.3
# 2286                            0.740       13.2
# 199                             0.520        8.6
# 517                             0.352        6.6
#
# [330 rows x 19 columns]
#       Life expectancy
# 1559             63.3
# 1976             62.7
# 1012             61.9
# 772              73.4
# 1604             77.9
# ...               ...
# 257              70.0
# 1040             78.7
# 2733             77.0
# 675              81.0
# 1658             61.4
#
# [1319 rows x 1 columns]
#       Life expectancy
# 0                65.0
# 2737             67.7
# 34               75.3
# 2715             61.5
# 2025             68.1
# ...               ...
# 2482             69.3
# 359              73.4
# 2286             72.4
# 199              69.1
# 517              49.2
#
# [330 rows x 1 columns]

# %%
correlation_matrix = x.corr()
print(correlation_matrix)
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix,annot=True,cmap="coolwarm")
# Out:
#                                      Year  Adult Mortality  infant deaths  \
# Year                             1.000000        -0.037092       0.008029
# Adult Mortality                 -0.037092         1.000000       0.042450
# infant deaths                    0.008029         0.042450       1.000000
# Alcohol                         -0.113365        -0.175535      -0.106217
# percentage expenditure           0.069553        -0.237610      -0.090765
# Hepatitis B                      0.114897        -0.105225      -0.231769
# Measles                         -0.053822        -0.003967       0.532680
#  BMI                             0.005739        -0.351542      -0.234425
# under-five deaths                0.010479         0.060365       0.996906
# Polio                           -0.016699        -0.199853      -0.156929
# Total expenditure                0.059493        -0.085227      -0.146951
# Diphtheria                       0.029641        -0.191429      -0.161871
#  HIV                            -0.123405         0.550691       0.007712
# GDP                              0.096421        -0.255035      -0.098092
# Population                       0.012567        -0.015012       0.671758
#  thinness  1-19 years            0.019757         0.272230       0.463415
#  thinness 5-9 years              0.014122         0.286723       0.461908
# Income composition of resources  0.122892        -0.442203      -0.134754
# Schooling                        0.088732        -0.421171      -0.214372
#
#                                   Alcohol  percentage expenditure  \
# Year                            -0.113365                0.069553
# Adult Mortality                 -0.175535               -0.237610
# infant deaths                   -0.106217               -0.090765
# Alcohol                          1.000000                0.417047
# percentage expenditure           0.417047                1.000000
# Hepatitis B                      0.109889                0.016760
# Measles                         -0.050110               -0.063071
#  BMI                             0.353396                0.242738
# under-five deaths               -0.101082               -0.092158
# Polio                            0.240315                0.128626
# Total expenditure                0.214885                0.183872
# Diphtheria                       0.242951                0.134813
#  HIV                            -0.027113               -0.095085
# GDP                              0.443433                0.959299
# Population                      -0.028880               -0.016792
#  thinness  1-19 years           -0.403755               -0.255035
#  thinness 5-9 years             -0.386208               -0.255635
# Income composition of resources  0.561074                0.402170
# Schooling                        0.616975                0.422088
#
#                                  Hepatitis B  Measles       BMI   \
# Year                                0.114897 -0.053822  0.005739
# Adult Mortality                    -0.105225 -0.003967 -0.351542
# infant deaths                      -0.231769  0.532680 -0.234425
# Alcohol                             0.109889 -0.050110  0.353396
# percentage expenditure              0.016760 -0.063071  0.242738
# Hepatitis B                         1.000000 -0.124800  0.143302
# Measles                            -0.124800  1.000000 -0.153245
#  BMI                                0.143302 -0.153245  1.000000
# under-five deaths                  -0.240766  0.517506 -0.242137
# Polio                               0.463331 -0.057850  0.186268
# Total expenditure                   0.113327 -0.113583  0.189469
# Diphtheria                          0.588990 -0.058606  0.176295
#  HIV                               -0.094802 -0.003522 -0.210897
# GDP                                 0.041850 -0.064768  0.266114
# Population                         -0.129723  0.321946 -0.081416
#  thinness  1-19 years              -0.129406  0.180642 -0.547018
#  thinness 5-9 years                -0.133251  0.174946 -0.554094
# Income composition of resources     0.184921 -0.058277  0.510505
# Schooling                           0.215182 -0.115660  0.554844
#
#                                  under-five deaths      Polio  \
# Year                                       0.010479 -0.016699
# Adult Mortality                            0.060365 -0.199853
# infant deaths                              0.996906 -0.156929
# Alcohol                                   -0.101082  0.240315
# percentage expenditure                    -0.092158  0.128626
# Hepatitis B                               -0.240766  0.463331
# Measles                                    0.517506 -0.057850
#  BMI                                      -0.242137  0.186268
# under-five deaths                          1.000000 -0.171164
# Polio                                     -0.171164  1.000000
# Total expenditure                         -0.145803  0.119768
# Diphtheria                                -0.178448  0.609245
#  HIV                                       0.019476 -0.107885
# GDP                                       -0.100331  0.156809
# Population                                 0.658680 -0.045387
#  thinness  1-19 years                      0.464785 -0.164070
#  thinness 5-9 years                        0.462289 -0.174489
# Income composition of resources           -0.148097  0.314682
# Schooling                                 -0.226013  0.350147
#
#                                  Total expenditure  Diphtheria        HIV  \
# Year                                      0.059493     0.029641 -0.123405
# Adult Mortality                          -0.085227    -0.191429  0.550691
# infant deaths                            -0.146951    -0.161871  0.007712
# Alcohol                                   0.214885     0.242951 -0.027113
# percentage expenditure                    0.183872     0.134813 -0.095085
# Hepatitis B                               0.113327     0.588990 -0.094802
# Measles                                  -0.113583    -0.058606 -0.003522
#  BMI                                      0.189469     0.176295 -0.210897
# under-five deaths                        -0.145803    -0.178448  0.019476
# Polio                                     0.119768     0.609245 -0.107885
# Total expenditure                         1.000000     0.129915  0.043101
# Diphtheria                                0.129915     1.000000 -0.117601
#  HIV                                      0.043101    -0.117601  1.000000
# GDP                                       0.180373     0.158438 -0.108081
# Population                               -0.079962    -0.039898 -0.027801
#  thinness  1-19 years                    -0.209872    -0.187242  0.172592
#  thinness 5-9 years                      -0.217865    -0.180952  0.183147
# Income composition of resources           0.183653     0.343262 -0.248590
# Schooling                                 0.243783     0.350398 -0.211840
#
#                                       GDP  Population   thinness  1-19 years  \
# Year                             0.096421    0.012567               0.019757
# Adult Mortality                 -0.255035   -0.015012               0.272230
# infant deaths                   -0.098092    0.671758               0.463415
# Alcohol                          0.443433   -0.028880              -0.403755
# percentage expenditure           0.959299   -0.016792              -0.255035
# Hepatitis B                      0.041850   -0.129723              -0.129406
# Measles                         -0.064768    0.321946               0.180642
#  BMI                             0.266114   -0.081416              -0.547018
# under-five deaths               -0.100331    0.658680               0.464785
# Polio                            0.156809   -0.045387              -0.164070
# Total expenditure                0.180373   -0.079962              -0.209872
# Diphtheria                       0.158438   -0.039898              -0.187242
#  HIV                            -0.108081   -0.027801               0.172592
# GDP                              1.000000   -0.020369              -0.277498
# Population                      -0.020369    1.000000               0.282529
#  thinness  1-19 years           -0.277498    0.282529               1.000000
#  thinness 5-9 years             -0.277959    0.277913               0.927913
# Income composition of resources  0.446856   -0.008132              -0.453679
# Schooling                        0.467947   -0.040312              -0.491199
#
#                                   thinness 5-9 years  \
# Year                                        0.014122
# Adult Mortality                             0.286723
# infant deaths                               0.461908
# Alcohol                                    -0.386208
# percentage expenditure                     -0.255635
# Hepatitis B                                -0.133251
# Measles                                     0.174946
#  BMI                                       -0.554094
# under-five deaths                           0.462289
# Polio                                      -0.174489
# Total expenditure                          -0.217865
# Diphtheria                                 -0.180952
#  HIV                                        0.183147
# GDP                                        -0.277959
# Population                                  0.277913
#  thinness  1-19 years                       0.927913
#  thinness 5-9 years                         1.000000
# Income composition of resources            -0.438484
# Schooling                                  -0.472482
#
#                                  Income composition of resources  Schooling
# Year                                                    0.122892   0.088732
# Adult Mortality                                        -0.442203  -0.421171
# infant deaths                                          -0.134754  -0.214372
# Alcohol                                                 0.561074   0.616975
# percentage expenditure                                  0.402170   0.422088
# Hepatitis B                                             0.184921   0.215182
# Measles                                                -0.058277  -0.115660
#  BMI                                                    0.510505   0.554844
# under-five deaths                                      -0.148097  -0.226013
# Polio                                                   0.314682   0.350147
# Total expenditure                                       0.183653   0.243783
# Diphtheria                                              0.343262   0.350398
#  HIV                                                   -0.248590  -0.211840
# GDP                                                     0.446856   0.467947
# Population                                             -0.008132  -0.040312
#  thinness  1-19 years                                  -0.453679  -0.491199
#  thinness 5-9 years                                    -0.438484  -0.472482
# Income composition of resources                         1.000000   0.784741
# Schooling                                               0.784741   1.000000
# <Axes: >

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit([[0, 0], [1, 1], [2, 2]], [0, 1, 2])
reg.coef_
# Out:
# array([0.5, 0.5])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
lr_model = LinearRegression()
lr_model.fit(x_train, y_train)
lr_model_preds = lr_model.predict(x_test)
print(f'MSE = {mean_squared_error(y_true=y_test, y_pred=lr_model_preds)}')
print(f'MAE = {mean_absolute_error(y_true=y_test, y_pred=lr_model_preds)}')
print(f'R2 Score = {r2_score(y_true=y_test, y_pred=lr_model_preds)}')
# Out:
# MSE = 12.015724050986382
# MAE = 2.6451004562725253
# R2 Score = 0.8591745885914388
