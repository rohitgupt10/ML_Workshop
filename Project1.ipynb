# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.shape
# Out:
# (150, 6)

# %%
df.dropna(inplace=True,axis=0)
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (150, 6)

# %%
distinct_values=df['SepalLengthCm'].unique()
print(distinct_values)
# Out:
# [5.1 4.9 4.7 4.6 5.  5.4 4.4 4.8 4.3 5.8 5.7 5.2 5.5 4.5 5.3 7.  6.4 6.9
#  6.5 6.3 6.6 5.9 6.  6.1 5.6 6.7 6.2 6.8 7.1 7.6 7.3 7.2 7.7 7.4 7.9]

# %%
distinct_values=df['SepalWidthCm'].unique()
print(distinct_values)
# Out:
# [3.5 3.  3.2 3.1 3.6 3.9 3.4 2.9 3.7 4.  4.4 3.8 3.3 4.1 4.2 2.3 2.8 2.4
#  2.7 2.  2.2 2.5 2.6]

# %%
distinct_values=df['PetalLengthCm'].unique()
print(distinct_values)
# Out:
# [1.4 1.3 1.5 1.7 1.6 1.1 1.2 1.  1.9 4.7 4.5 4.9 4.  4.6 3.3 3.9 3.5 4.2
#  3.6 4.4 4.1 4.8 4.3 5.  3.8 3.7 5.1 3.  6.  5.9 5.6 5.8 6.6 6.3 6.1 5.3
#  5.5 6.7 6.9 5.7 6.4 5.4 5.2]

# %%
distinct_values=df['PetalWidthCm'].unique()
print(distinct_values)
# Out:
# [0.2 0.4 0.3 0.1 0.5 0.6 1.4 1.5 1.3 1.6 1.  1.1 1.8 1.2 1.7 2.5 1.9 2.1
#  2.2 2.  2.4 2.3]

# %%
distinct_values=df['Species'].unique()
print(distinct_values)
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
distinct_counts1=df.groupby('Species')['SepalLengthCm'].nunique()
print(distinct_counts1)
# Out:
# Species
# Iris-setosa        15
# Iris-versicolor    21
# Iris-virginica     21
# Name: SepalLengthCm, dtype: int64

# %%
distinct_category = distinct_counts1.index.tolist()  
message_count = distinct_counts1.values.tolist()  

fig, ax = plt.subplots(figsize=(8, 5))  
ax.bar(distinct_category, message_count, color='red')  
ax.set_title("Bar Graph")  
ax.set_xlabel("Species")  
ax.set_ylabel("Sepal Length in Cm")
# Out:
# Text(0, 0.5, 'Sepal Length in Cm')

# %%
distinct_counts2=df.groupby('Species')['SepalWidthCm'].nunique()
print(distinct_counts2)
# Out:
# Species
# Iris-setosa        16
# Iris-versicolor    14
# Iris-virginica     13
# Name: SepalWidthCm, dtype: int64

# %%
distinct_category = distinct_counts2.index.tolist()  
message_count = distinct_counts2.values.tolist()  

fig, ax = plt.subplots(figsize=(8, 5))  
ax.bar(distinct_category, message_count, color='green')  
ax.set_title("Bar Graph")  
ax.set_xlabel("Species")  
ax.set_ylabel("Sepal Length in Cm")
# Out:
# Text(0, 0.5, 'Sepal Length in Cm')

# %%
distinct_counts3=df.groupby('Species')['PetalLengthCm'].nunique()
print(distinct_counts3)
# Out:
# Species
# Iris-setosa         9
# Iris-versicolor    19
# Iris-virginica     20
# Name: PetalLengthCm, dtype: int64

# %%
distinct_category = distinct_counts3.index.tolist()  
message_count = distinct_counts3.values.tolist()  

fig, ax = plt.subplots(figsize=(8, 5))  
ax.bar(distinct_category, message_count, color='blue')  
ax.set_title("Bar Graph")  
ax.set_xlabel("Species")  
ax.set_ylabel("Sepal Length in Cm")
# Out:
# Text(0, 0.5, 'Sepal Length in Cm')

# %%
distinct_counts4=df.groupby('Species')['PetalWidthCm'].nunique()
print(distinct_counts4)
# Out:
# Species
# Iris-setosa         6
# Iris-versicolor     9
# Iris-virginica     12
# Name: PetalWidthCm, dtype: int64

# %%
message_count = distinct_counts4.values.tolist()
distinct_category = distinct_counts4.index.tolist()
print(message_count)
print(distinct_category)
fig, ax = plt.subplots()
ax.pie(message_count, labels=distinct_category)
plt.show()
# Out:
# [6, 9, 12]
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
distinct_category = distinct_counts4.index.tolist()  
message_count = distinct_counts4.values.tolist()  

fig, ax = plt.subplots(figsize=(8, 5))  
ax.bar(distinct_category, message_count, color='yellow')  
ax.set_title("Bar Graph")  
ax.set_xlabel("Species")  
ax.set_ylabel("Petal Width in Cm")
# Out:
# Text(0, 0.5, 'Petal Width in Cm')

# %%
X= df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
Y= df['Species']
print(X.head())
print(Y.head())
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=45)

# %%
clf= tree.DecisionTreeClassifier(max_depth=5)
clf= clf.fit(x_train,y_train)
y_predict=clf.predict(x_test)
print(y_predict)
# Out:
# ['Iris-setosa' 'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-setosa' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-setosa' 'Iris-virginica'
#  'Iris-virginica' 'Iris-setosa' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-virginica' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-versicolor']

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
plt.figure(figsize =(15,10))
tree.plot_tree(clf,filled=True)
# Out:
# [Text(0.5416666666666666, 0.9166666666666666, 'x[3] <= 0.75\ngini = 0.666\nsamples = 120\nvalue = [39, 43, 38]'),
#  Text(0.4583333333333333, 0.75, 'gini = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(0.5, 0.8333333333333333, 'True  '),
#  Text(0.625, 0.75, 'x[3] <= 1.75\ngini = 0.498\nsamples = 81\nvalue = [0, 43, 38]'),
#  Text(0.5833333333333333, 0.8333333333333333, '  False'),
#  Text(0.4166666666666667, 0.5833333333333334, 'x[2] <= 5.35\ngini = 0.124\nsamples = 45\nvalue = [0, 42, 3]'),
#  Text(0.3333333333333333, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.087\nsamples = 44\nvalue = [0, 42, 2]'),
#  Text(0.16666666666666666, 0.25, 'x[2] <= 4.95\ngini = 0.046\nsamples = 42\nvalue = [0, 41, 1]'),
#  Text(0.08333333333333333, 0.08333333333333333, 'gini = 0.0\nsamples = 40\nvalue = [0, 40, 0]'),
#  Text(0.25, 0.08333333333333333, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.5, 0.25, 'x[1] <= 2.75\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
# ...

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_predict))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       0.88      1.00      0.93         7
#  Iris-virginica       1.00      0.92      0.96        12
#
#        accuracy                           0.97        30
#       macro avg       0.96      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30

# %%
import seaborn as sns
sns.set_theme(style="ticks")
df=sns.load_dataset("iris")
sns.pairplot(df,hue="species")
